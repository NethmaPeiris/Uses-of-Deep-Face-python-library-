# %%
# !pip install deepface

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
test_img_1 = cv2.imread('/content/face 1.jpg')

# %%
cv2_imshow(test_img_1)
# Out:
# <PIL.Image.Image image mode=RGB size=650x572>

# %%
result_1=DeepFace.analyze(test_img_1,actions=['emotion'])

# %%
print(result_1)
# Out:
# [{'emotion': {'angry': 54.214322566986084, 'disgust': 45.77637314796448, 'fear': 0.006136787123978138, 'happy': 5.455966407830193e-10, 'sad': 9.962669764718157e-05, 'surprise': 0.003065367855015211, 'neutral': 1.8522592348801936e-07}, 'dominant_emotion': 'angry', 'region': {'x': 230, 'y': 139, 'w': 190, 'h': 190, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.93}]

# %%
result_2=DeepFace.analyze(test_img_1,actions=['age'])

# %%
print(result_2)
# Out:
# [{'age': 31, 'region': {'x': 230, 'y': 139, 'w': 190, 'h': 190, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.93}]

# %%
test_img_2 = cv2.imread('/content/face 2.jpg')

# %%
cv2_imshow(test_img_2)
# Out:
# <PIL.Image.Image image mode=RGB size=251x201>

# %%
result_3=DeepFace.analyze(test_img_2,actions=['emotion'])

# %%
print(result_3)
# Out:
# [{'emotion': {'angry': 4.07670688847498e-09, 'disgust': 1.947975646692546e-13, 'fear': 0.00010032147142798212, 'happy': 99.9909162532191, 'sad': 9.995142081531173e-05, 'surprise': 3.818108040880309e-05, 'neutral': 0.008846293022087302}, 'dominant_emotion': 'happy', 'region': {'x': 58, 'y': 46, 'w': 113, 'h': 113, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.9}]
